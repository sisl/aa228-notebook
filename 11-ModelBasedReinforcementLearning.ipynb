# %% [markdown]
# # Model-Based Reinforcement Learning

# %%
using Interact
using Reactive
include("rl.jl")
g = DMUGridWorld()
value = Reactive.value;
# Out:
# HTML{String}("    <script class='js-collapse-script'>\n        var curMatch =\n            window.location.href\n            .match(/(.*?)\\/notebooks\\/.*\\.ipynb/);\n\n        curMatch = curMatch ||\n            window.location.href\n            .match(/(.*?)\\/apps\\/.*\\.ipynb/);\n\n        if ( curMatch ) {\n            \$('head').append('<base href=\"' + curMatch[1] + '/\">');\n        }\n    </script>\n")
# HTML{String}("<script class='js-collapse-script' src='/assetserver/6137858c288834145b218ff0d1876943f939c631-assets/webio/dist/bundle.js'></script>")
# HTML{String}("<script class='js-collapse-script' src='/assetserver/6137858c288834145b218ff0d1876943f939c631-assets/providers/ijulia_setup.js'></script>")
# HTML{String}("  <script class='js-collapse-script'>\n    \$('.js-collapse-script').parent('.output_subarea').css('padding', '0');\n  </script>\n")

# %% [markdown]
# This is a simulation that illustrates maximum likelihood model-based reinforcement learning.

# %%
using Random
Random.seed!(2)
maxSteps = 25

policy = MLRL(states(g), actions(g), epsilon=0.2)
script = [3,13,23,33,43,53,63,73,83,84,85,75,65,64,63,62]
(S, R, V) = simulate(g, maxSteps, policy, script=script)
@manipulate for steps in 1:maxSteps
    plot(g, V[steps], curState = S[steps])
end
# Out:
# Widget{:manipulate,Any}(OrderedDict{Symbol,Any}(:steps=>Widget{:slider,Int64}(OrderedDict{Symbol,Any}(:changes=>Observable{Int64}("ob_02", 0, Any[SyncCallback(Scope("knockout-component-49cfff43-531d-4c8b-ad25-54af764d648a", Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :label), Any["steps"], Dict{Symbol,Any}(:className=>"interact ",:style=>Dict{Any,Any}(:padding=>"5px 10px 0px 10px")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"text-align:right;width:18%")), 2), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :input), Any[], Dict{Symbol,Any}(:max=>25,:min=>1,:attributes=>Dict{Any,Any}(:type=>"range",Symbol("data-bind")=>"numericValue: value, valueUpdate: 'input', event: {change : function () {this.changes(this.changes()+1)}}","orient"=>"horizontal"),:step=>1,:className=>"slider slider is-fullwidth",:style=>Dict{Any,Any}()), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"flex-grow:1; margin: 0 2%")), 1), Node{DOM}(DOM(:html, :div), Any[Node{DOM}(DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes=>Dict("data-bind"=>"text: value")), 0)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"width:18%")), 1)], Dict{Symbol,Any}(:attributes=>Dict("style"=>"display:flex; justify-content:center; align-items:center;")), 7), Dict{String,Tuple{Observables.AbstractObservable,Union{Nothing, Bool}}}("changes"=>(Observable{Int64}(#= circular reference @-6 =#), nothing),"value"=>(Observable{Int64}("ob_01", 13, Any[SyncCallback(Scope(#= circular reference @-6 =#), SyncCallback(Scope(#= circular reference @-7 =#), ##40#42{Scope,String}(Scope(#= circular reference @-8 =#), "value"))), #g#15{##16#17{##41#43,Observable{Any}},Tuple{Observable{Int64}}}(##16#17{##41#43,Observable{Any}}(##41#43(), Observable{Any}("ob_03", TikzPicture("\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (0.0,9.0) rectangle +(1.0,1.0);\n\\node[above right] at (0.0, 9.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (0.0,8.0) rectangle +(1.0,1.0);\n\\node[above right] at (0.0, 8.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{220.96028715,255.0,220.96028715}\n\\fill[currentcolor] (0.0,7.0) rectangle +(1.0,1.0);\n\\node[above right] at (0.0, 7.0) {\$1.33\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (0.0,6.0) rectangle +(1.0,1.0);\n\\node[above right] at (0.0, 6.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (0.0,5.0) rectangle +(1.0,1.0);\n\\node[above right] at (0.0, 5.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (0.0,4.0) rectangle +(1.0,1.0);\n\\node[above right] at (0.0, 4.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (0.0,3.0) rectangle +(1.0,1.0);\n\\node[above right] at (0.0, 3.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (0.0,2.0) rectangle +(1.0,1.0);\n\\node[above right] at (0.0, 2.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (0.0,1.0) rectangle +(1.0,1.0);\n\\node[above right] at (0.0, 1.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (0.0,0.0) rectangle +(1.0,1.0);\n\\node[above right] at (0.0, 0.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (1.0,9.0) rectangle +(1.0,1.0);\n\\node[above right] at (1.0, 9.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (1.0,8.0) rectangle +(1.0,1.0);\n\\node[above right] at (1.0, 8.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB}{214.3447635,255.0,214.3447635}\n\\fill[currentcolor] (1.0,7.0) rectangle +(1.0,1.0);\n\\node[above right] at (1.0, 7.0) {\$1.59\$};\n\\definecolor{currentcolor}{RGB}{255.0,255.0,255.0}\n\\fill[currentcolor] (1.0,6.0) rectangle +(1.0,1.0);\n\\node[above right] at (1.0, 6.0) {\$0.00\$};\n\\definecolor{currentcolor}{RGB} ...
# ┌ Warning: tikzpicture.svg already exists, overwriting!
# └ @ TikzPictures /home/shushman/.julia/packages/TikzPictures/b9irC/src/TikzPictures.jl:414
